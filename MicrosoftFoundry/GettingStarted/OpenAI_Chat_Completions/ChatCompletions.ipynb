# %% [markdown]
# ## Calling our OpenAI Model from Microsoft Foundry

# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
# Out:
# Requirement already satisfied: azure-ai-projects==2.0.0b2 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (2.0.0b2)
# Collecting openai==1.109.1
#   Downloading openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: python-dotenv in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (1.2.1)
# Requirement already satisfied: azure-identity in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (1.26.0b1)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from azure-ai-projects==2.0.0b2) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from azure-ai-projects==2.0.0b2) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from azure-ai-projects==2.0.0b2) (12.28.0b1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from openai==1.109.1) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from openai==1.109.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from openai==1.109.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from openai==1.109.1) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from openai==1.109.1) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from openai==1.109.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from openai==1.109.1) (4.67.1)
# Requirement already satisfied: cryptography>=2.5 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from azure-identity) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai==1.109.1) (3.11)
# Requirement already satisfied: requests>=2.21.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: certifi in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1) (0.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.4.2)
# Requirement already satisfied: colorama in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from tqdm>4->openai==1.109.1) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lloyd\gitprojects\ai-102\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.6.1)
# Downloading openai-1.109.1-py3-none-any.whl (948 kB)
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/948.6 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/948.6 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/948.6 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/948.6 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/948.6 kB ? eta -:--:--
#    --------------------- ---------------- 524.3/948.6 kB 254.0 kB/s eta 0:00:02
#    --------------------- ---------------- 524.3/948.6 kB 254.0 kB/s eta 0:00:02
#    --------------------- ---------------- 524.3/948.6 kB 254.0 kB/s eta 0:00:02
#    --------------------- ---------------- 524.3/948.6 kB 254.0 kB/s eta 0:00:02
#    --------------------- ---------------- 524.3/948.6 kB 254.0 kB/s eta 0:00:02
#    ------------------------------- ------ 786.4/948.6 kB 256.1 kB/s eta 0:00:01
#    ------------------------------- ------ 786.4/948.6 kB 256.1 kB/s eta 0:00:01
#    ------------------------------- ------ 786.4/948.6 kB 256.1 kB/s eta 0:00:01
#    -------------------------------------- 948.6/948.6 kB 261.5 kB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 2.9.0
#     Uninstalling openai-2.9.0:
#       Successfully uninstalled openai-2.9.0
# Successfully installed openai-1.109.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openai-agents 0.6.2 requires openai<3,>=2.8.0, but you have openai 1.109.1 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Setting up the Environment Variables

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
load_dotenv()

foundry_project_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")
model_deployment_name = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# ### Setting up the AI Foundry Project Client

# %%
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential()
)

# %%
print("FOUNDRY_PROJECT_ENDPOINT=", foundry_project_endpoint)
print("MODEL_DEPLOYMENT_NAME=", model_deployment_name)
# Out:
# FOUNDRY_PROJECT_ENDPOINT= https://e5sweden.services.ai.azure.com/api/projects/Sweden
# MODEL_DEPLOYMENT_NAME= gpt-5.1

# %% [markdown]
# ### Setting up the OpenAI Client

# %%
openai_client = project_client.get_openai_client()

# %% [markdown]
# ### Sending a Request to the OpenAI Model

# %%
response = openai_client.responses.create(
    model=model_deployment_name,
    instructions="You are a helpful AI assistant.",
    input = "Can you tell me about Microsoft Foundry?"
)

print(f"Response output: {response.output_text}")
# Out:
# Response output: Microsoft Foundry is a program and set of tools from Microsoft aimed at helping developers, startups, and enterprises build AI-powered applications quickly and reliably on Microsoft platforms—especially using Azure and, more recently, the “Copilot stack” (e.g., Azure OpenAI Service, GitHub Copilot, etc.).
#
# The name “Foundry” has been used in a few, related contexts:
#
# 1. **Microsoft AI Foundry (Azure / Copilot-related)**
#    - A collection of:
#      - **Tools and templates** for building copilots and AI apps (prompt engineering, orchestration, evaluation).
#      - **Reference architectures** that show how to combine Azure OpenAI, search/indexing, data storage, and application layers.
#      - **Best practices** for responsible AI, security, and governance.
#    - Targeted at:
#      - Enterprises that want to build internal copilots.
#      - Partners and system integrators building solutions on the Microsoft AI stack.
#    - Often used alongside:
#      - Azure OpenAI Service
#      - Azure AI Studio / Prompt Flow
#      - GitHub Copilot and other Copilot experiences.
#
# 2. **Microsoft Foundry as a developer/startup support program**
#    - In some regions and partner ecosystems, “Foundry” refers to:
#      - Programs that give startups and ISVs access to Azure credits, technical mentoring, and go‑to‑market support.
#      - Hands-on guidance to build production-ready solutions on Azure (including AI).
#    - These may be run locally (e.g., by Microsoft regional teams or partner organizations), so details can vary.
#
# 3. **Foundry-style internal and partner accelerators**
#    - Microsoft and partner firms sometimes run “Foundry” or “AI Foundry” accelerators:
#      - Short, intensive engagements where architects and engineers help teams design and build a pilot solution.
#      - Focus on architecture, MLOps/LLMOps, and integration with existing systems.
#
# If you tell me the context you’re interested in (enterprise AI, startup support, developer tools, or something you heard in a specific announcement), I can give a more precise description and point you to the most relevant resources and typical use cases.
